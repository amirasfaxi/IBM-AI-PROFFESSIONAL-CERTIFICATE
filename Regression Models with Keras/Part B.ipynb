# %% [markdown]
# <h1>Regression Models with Keras  Part B </h1>

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this project, you will build a regression model using the Keras library to model the same data about concrete compressive strength that we used in labs 3. For your convenience, the data can be found here again: https://cocl.us/concrete_data. To recap, the predictors in the data of concrete strength include:
#
# Cement Blast Furnace Slag Fly Ash Water Superplasticizer Coarse Aggregate Fine Aggregate
#
# The four parts of the capstone:
#
# A. Build a baseline model
# B. Normalize the data
# C. Increate the number of epochs
# D. Increase the number of hidden layers

# %% [markdown]
# ## Download and Clean The Dataset

# %% [markdown]
# Let's start by importing the pandas and the Numpy libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's download the data and read it into a pandas dataframe.

# %%
#!wget -O concrete_data.csv 'https://cocl.us/concrete_data'

concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# let's check the size of data

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# there are approximately 1000 samples to train our model on

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# ## Data seperation to predictors and target

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# ## Normalize the data

# %%
# normalize the data by substracting the mean and dividing by the standard deviation.
# Normalize the data
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to _ncols since we will need this number when building our network.

# %%
n_cols = predictors.shape[1] # number of predictors

# %% [markdown]
# ## Import Keras

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Build a Neural Network

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# 1.split 30% for testing without normalize
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42)

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# fit the model
model.fit(predictors, target, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 33/33 - 0s - loss: 541553.4375 - 337ms/epoch - 10ms/step
# Epoch 2/50
# 33/33 - 0s - loss: 237412.9844 - 35ms/epoch - 1ms/step
# Epoch 3/50
# 33/33 - 0s - loss: 69646.9922 - 30ms/epoch - 896us/step
# Epoch 4/50
# 33/33 - 0s - loss: 13878.2217 - 34ms/epoch - 1ms/step
# Epoch 5/50
# 33/33 - 0s - loss: 4360.3677 - 29ms/epoch - 868us/step
# Epoch 6/50
# 33/33 - 0s - loss: 3496.1743 - 27ms/epoch - 807us/step
# Epoch 7/50
# 33/33 - 0s - loss: 3261.5271 - 30ms/epoch - 902us/step
# Epoch 8/50
# 33/33 - 0s - loss: 3039.7195 - 31ms/epoch - 944us/step
# Epoch 9/50
# 33/33 - 0s - loss: 2830.2217 - 36ms/epoch - 1ms/step
# Epoch 10/50
# 33/33 - 0s - loss: 2618.1765 - 32ms/epoch - 958us/step
# Epoch 11/50
# 33/33 - 0s - loss: 2420.7290 - 29ms/epoch - 884us/step
# Epoch 12/50
# 33/33 - 0s - loss: 2230.5159 - 31ms/epoch - 951us/step
# Epoch 13/50
# 33/33 - 0s - loss: 2054.4460 - 28ms/epoch - 843us/step
# Epoch 14/50
# 33/33 - 0s - loss: 1888.8442 - 27ms/epoch - 827us/step
# Epoch 15/50
# 33/33 - 0s - loss: 1737.3802 - 28ms/epoch - 850us/step
# Epoch 16/50
# 33/33 - 0s - loss: 1595.5365 - 28ms/epoch - 835us/step
# Epoch 17/50
# 33/33 - 0s - loss: 1467.7037 - 30ms/epoch - 924us/step
# Epoch 18/50
# 33/33 - 0s - loss: 1351.9236 - 29ms/epoch - 864us/step
# Epoch 19/50
# 33/33 - 0s - loss: 1244.7965 - 28ms/epoch - 841us/step
# Epoch 20/50
# 33/33 - 0s - loss: 1141.3584 - 28ms/epoch - 850us/step
# Epoch 21/50
# 33/33 - 0s - loss: 1054.1309 - 32ms/epoch - 960us/step
# Epoch 22/50
# 33/33 - 0s - loss: 971.5106 - 29ms/epoch - 877us/step
# Epoch 23/50
# 33/33 - 0s - loss: 898.7946 - 28ms/epoch - 839us/step
# Epoch 24/50
# 33/33 - 0s - loss: 833.0062 - 28ms/epoch - 835us/step
# Epoch 25/50
# 33/33 - 0s - loss: 774.6646 - 27ms/epoch - 822us/step
# Epoch 26/50
# 33/33 - 0s - loss: 724.1079 - 28ms/epoch - 836us/step
# Epoch 27/50
# 33/33 - 0s - loss: 676.0165 - 27ms/epoch - 813us/step
# Epoch 28/50
# 33/33 - 0s - loss: 634.6995 - 26ms/epoch - 793us/step
# Epoch 29/50
# 33/33 - 0s - loss: 595.8901 - 27ms/epoch - 816us/step
# Epoch 30/50
# 33/33 - 0s - loss: 562.1081 - 31ms/epoch - 928us/step
# Epoch 31/50
# 33/33 - 0s - loss: 532.2156 - 28ms/epoch - 860us/step
# Epoch 32/50
# 33/33 - 0s - loss: 505.2216 - 28ms/epoch - 847us/step
# Epoch 33/50
# 33/33 - 0s - loss: 482.4875 - 29ms/epoch - 869us/step
# Epoch 34/50
# 33/33 - 0s - loss: 461.6716 - 27ms/epoch - 829us/step
# Epoch 35/50
# 33/33 - 0s - loss: 440.8198 - 28ms/epoch - 837us/step
# Epoch 36/50
# 33/33 - 0s - loss: 423.6136 - 29ms/epoch - 889us/step
# Epoch 37/50
# 33/33 - 0s - loss: 408.4687 - 26ms/epoch - 799us/step
# Epoch 38/50
# 33/33 - 0s - loss: 393.7610 - 28ms/epoch - 846us/step
# Epoch 39/50
# 33/33 - 0s - loss: 380.5627 - 30ms/epoch - 911us/step
# Epoch 40/50
# 33/33 - 0s - loss: 369.4760 - 27ms/epoch - 805us/step
# Epoch 41/50
# 33/33 - 0s - loss: 356.8068 - 31ms/epoch - 933us/step
# Epoch 42/50
# 33/33 - 0s - loss: 345.5046 - 28ms/epoch - 841us/step
# Epoch 43/50
# 33/33 - 0s - loss: 335.2504 - 29ms/epoch - 887us/step
# Epoch 44/50
# 33/33 - 0s - loss: 326.2828 - 29ms/epoch - 869us/step
# Epoch 45/50
# 33/33 - 0s - loss: 318.2189 - 27ms/epoch - 833us/step
# Epoch 46/50
# 33/33 - 0s - loss: 308.9818 - 28ms/epoch - 863us/step
# Epoch 47/50
# 33/33 - 0s - loss: 301.0623 - 28ms/epoch - 834us/step
# Epoch 48/50
# 33/33 - 0s - loss: 292.9754 - 27ms/epoch - 829us/step
# Epoch 49/50
# 33/33 - 0s - loss: 286.1382 - 30ms/epoch - 900us/step
# Epoch 50/50
# 33/33 - 0s - loss: 277.9406 - 29ms/epoch - 873us/step

# %% [markdown]
# ## Evaluate the model on the test data.

# %%
model_evaluation = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
model_evaluation
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 256.4826
# 256.4826354980469

# %% [markdown]
# ## The mean squared error between the predicted concrete strength and the actual concrete strength

# %%
mean_square_error = mean_squared_error(y_test, y_pred)
mean = np.mean(mean_square_error)
standard_deviation = np.std(mean_square_error)
print(mean, standard_deviation)
# Out:
# 256.48263699712 0.0

# %% [markdown]
# ## List of 50 mean squared errors with report of mean and the standard deviation of the mean squared errors

# %%
total_mean_squared_errors = 50
epochs = 50
mean_squared_errors = []
for i in range(0, total_mean_squared_errors):
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=i)
    model.fit(X_train, y_train, epochs=epochs, verbose=0)
    MSE = model.evaluate(X_test, y_test, verbose=0)
    print("MSE "+str(i+1)+": "+str(MSE))
    y_pred = model.predict(X_test)
    mean_square_error = mean_squared_error(y_test, y_pred)
    mean_squared_errors.append(mean_square_error)

mean_squared_errors = np.array(mean_squared_errors)
mean = np.mean(mean_squared_errors)
standard_deviation = np.std(mean_squared_errors)

print('\n')
print("Mean and standard deviation of " +str(total_mean_squared_errors) + " mean squared errors without normalized data. \n Total number of epochs for each training is: " +str(epochs) + "\n")
print("Mean: "+str(mean))
print("Standard Deviation: "+str(standard_deviation))
# Out:
# MSE 1: 150.06663513183594
# MSE 2: 138.96234130859375
# MSE 3: 113.8921890258789
# MSE 4: 128.50930786132812
# MSE 5: 143.475341796875
# MSE 6: 109.77851867675781
# MSE 7: 144.95388793945312
# MSE 8: 100.97129821777344
# MSE 9: 119.30418395996094
# MSE 10: 127.28488159179688
# MSE 11: 106.13741302490234
# MSE 12: 116.47370910644531
# MSE 13: 115.5986328125
# MSE 14: 121.37665557861328
# MSE 15: 116.42910766601562
# MSE 16: 111.08041381835938
# MSE 17: 105.651611328125
# MSE 18: 99.1829605102539
# MSE 19: 97.2935791015625
# MSE 20: 128.48020935058594
# MSE 21: 96.56719970703125
# MSE 22: 102.92137908935547
# MSE 23: 121.94683837890625
# MSE 24: 103.62215423583984
# MSE 25: 110.03074645996094
# MSE 26: 100.817138671875
# MSE 27: 130.73028564453125
# MSE 28: 110.32652282714844
# MSE 29: 109.99884796142578
# MSE 30: 125.49868774414062
# MSE 31: 131.3505401611328
# MSE 32: 111.37294006347656
# MSE 33: 109.42801666259766
# MSE 34: 129.76463317871094
# MSE 35: 123.4890365600586
# MSE 36: 137.22572326660156
# MSE 37: 120.76641845703125
# MSE 38: 116.2818832397461
# MSE 39: 134.90289306640625
# MSE 40: 120.08615112304688
# MSE 41: 120.28937530517578
# MSE 42: 111.72042846679688
# MSE 43: 111.9822998046875
# MSE 44: 115.27037811279297
# MSE 45: 139.1645050048828
# MSE 46: 115.94656372070312
